# %% [markdown]
# # Creating a TPT report in a Panda dataframe in python

# %% [markdown]
# ### Imports

# %%
import pyodbc
from pathlib import Path
import pandas as pd
import numpy as np
from collections import OrderedDict

# %% [markdown]
# ### Required variables

# %%
# database connector
connector = pyodbc.connect('driver={SQL Server};'
                           'Server=DESKTOP-RGN6M86;'
                           'Database=intranet;'
                           'Trusted_Connection=yes;')
# date
DATE = "2020-12-31"
# client's name
CLIENT = "BILMI"
# shareclass' ISIN code
ISIN = "LU1689732417"
# portfolio file
portfolio_file_name = "template_Portfolio_BILMI.xlsx"
AODB_file_name = "AO Data Base v0.8.xlsx"
BBG_file_name = "AO_Bloomberg_Template_SII.xlsx"
root_data_path = Path('C:/Users/Hugo Durand/Workspace/data')
portfolio_file_path = root_data_path / portfolio_file_name
AODB_file_path = root_data_path / AODB_file_name
BBG_file_path = root_data_path / BBG_file_name

# %%
root_path = Path("C:/Users/Hugo Durand/Workspace/data")
file_name = "20201231_BILMI_BIL Invest Bonds USD Corporate Investment Grade - P USD CAP_LU1689732417_original.xlsx"
    
report = pd.read_excel(root_path / file_name,
                       sheet_name="Report",
                      skiprows=2)
i=130

#report.iloc[:,i:i+10]
#report["Unnamed: 21"]
report.drop(["17b_Asset / Liability", 
             "Unnamed: 21",
             "=AB4+EG4",
             "=Z4-EG4",
             "=AF4+EI4",
             "=AD4-EI4",
             "Unnamed: 34",
             "Unnamed: 36",
             "Unnamed: 136",
             "Unnamed: 138",
             "Currency conversion Pay attention to GBp !!!!!!!!!",
             "Diff in ccy?",
             "ccy main",
             "ccy underluying"
            ], axis=1, inplace=True)

report.rename(columns={
        "4_Portfolio currency ( B )": 
            "4_Portfolio currency (B)",
        "20_Contract size for derivatives ": 
            "20_Contract size for derivatives",
        "22_Market valuation in quotation currency  ( A ) ": 
            "22_Market valuation in quotation currency (A)",
        "24_Market valuation in portfolio currency  (B) ":
            "24_Market valuation in portfolio currency (B)",
        "29_Market exposure amount for the 3rd currency in quotation currency of the underlying asset ( C )":
            "29_Market exposure amount for the 3rd currency in quotation currency of the underlying asset (C)",
        "35_Identification type for interest rate index ": 
            "35_Identification type for interest rate index",
        "58b_Nature of the TRANCHE ": 
            "58b_Nature of the TRANCHE",
        "62_Conversion factor (convertibles)/ concordance factor  / parity (options)": 
            "62_Conversion factor (convertibles) / concordance factor / parity (options)",
        "71_Quotation currency of the underlying asset ( C )": 
            "71_Quotation currency of the underlying asset (C)",
        "123_Fund CIC code ":
            "123_Fund CIC code"
        }, inplace=True)
    
report.shape
# Out:
# (156, 140)

# %% [markdown]
# ### Define required fields

# %%
with open("../python/fields.txt", "r") as f:
    fields = f.read().splitlines()
TPT_fields = OrderedDict.fromkeys(fields)
#print(TPT_fields)
for field, access in TPT_fields.items():
    print(field, access)
# Out:
# 1_Portfolio identifying data None
# 2_Type of identification code for the fund share or portfolio None
# 3_Portfolio name None
# 4_Portfolio currency (B) None
# 5_Net asset valuation of the portfolio or the share class in portfolio currency None
# 6_Valuation date None
# 7_Reporting date None
# 8_Share price None
# 8b_Total number of shares None
# 9_% cash None
# 10_Portfolio Modified Duration None
# 11_Complete SCR Delivery None
# 12_CIC code of the instrument None
# 13_Economic zone of the quotation place None
# 14_Identification code of the financial instrument None
# 15_Type of identification code for the instrument None
# 16_Grouping code for multiple leg instruments None
# 17_Instrument name None
# 18_Quantity None
# 19_Nominal amount None
# 20_Contract size for derivatives None
# 21_Quotation currency (A) None
# 22_Market valuation in quotation currency (A) None
# 23_Clean market valuation in quotation currency (A) None
# 24_Market valuation in portfolio currency (B) None
# 25_Clean market valuation in portfolio currency (B) None
# 26_Valuation weight None
# 27_Market exposure amount in quotation currency (A) None
# 28_Market exposure amount in portfolio currency (B) None
# 29_Market exposure amount for the 3rd currency in quotation currency of the underlying asset (C) None
# 30_Market Exposure in weight None
# 31_Market exposure for the 3rd currency in weight over NAV None
# 32_Interest rate type None
# 33_Coupon rate None
# 34_Interest rate reference identification None
# 35_Identification type for interest rate index None
# 36_Interest rate index name None
# 37_Interest rate Margin None
# 38_Coupon payment frequency None
# 39_Maturity date None
# 40_Redemption type None
# 41_Redemption rate None
# 42_Callable / putable None
# 43_Call / put date None
# 44_Issuer / bearer option exercise None
# 45_Strike price for embedded (call/put) options None
# 46_Issuer name None
# 47_Issuer identification code None
# 48_Type of identification code for issuer None
# 49_Name of the group of the issuer None
# 50_Identification of the group None
# 51_Type of identification code for issuer group None
# 52_Issuer country None
# 53_Issuer economic area None
# 54_Economic sector None
# 55_Covered / not covered None
# 56_Securitisation None
# 57_Explicit guarantee by the country of issue None
# 58_Subordinated debt None
# 58b_Nature of the TRANCHE None
# 59_Credit quality step None
# 60_Call / Put / Cap / Floor None
# 61_Strike price None
# 62_Conversion factor (convertibles) / concordance factor / parity (options) None
# 63_Effective Date of Instrument None
# 64_Exercise type None
# 65_Hedging Rolling None
# 67_CIC code of the underlying asset None
# 68_Identification code of the underlying asset None
# 69_Type of identification code for the underlying asset None
# 70_Name of the underlying asset None
# 71_Quotation currency of the underlying asset (C) None
# 72_Last valuation price of the underlying asset None
# 73_Country of quotation of the underlying asset None
# 74_Economic Area of quotation of the underlying asset None
# 75_Coupon rate of the underlying asset None
# 76_Coupon payment frequency of the underlying asset None
# 77_Maturity date of the underlying asset None
# 78_Redemption profile of the underlying asset None
# 79_Redemption rate of the underlying asset None
# 80_Issuer name of the underlying asset None
# 81_Issuer identification code of the underlying asset None
# 82_Type of issuer identification code of the underlying asset None
# 83_Name of the group of the issuer of the underlying asset None
# 84_Identification of the group of the underlying asset None
# 85_Type of the group identification code of the underlying asset None
# 86_Issuer country of the underlying asset None
# 87_Issuer economic area of the underlying asset None
# 88_Explicit guarantee by the country of issue of the underlying asset None
# 89_Credit quality step of the underlying asset None
# 90_Modified Duration to maturity date None
# 91_Modified duration to next option exercise date None
# 92_Credit sensitivity None
# 93_Sensitivity to underlying asset price (delta) None
# 94_Convexity / gamma for derivatives None
# 94b_Vega None
# 95_Identification of the original portfolio for positions embedded in a fund None
# 97_SCR_Mrkt_IR_up weight over NAV None
# 98_SCR_Mrkt_IR_down weight over NAV None
# 99_SCR_Mrkt_Eq_type1 weight over NAV None
# 100_SCR_Mrkt_Eq_type2 weight over NAV None
# 101_SCR_Mrkt_Prop weight over NAV None
# 102_SCR_Mrkt_Spread_bonds weight over NAV None
# 103_SCR_Mrkt_Spread_structured weight over NAV None
# 104_SCR_Mrkt_Spread_derivatives_up weight over NAV None
# 105_SCR_Mrkt_Spread_derivatives_down weight over NAV None
# 105a_SCR_Mrkt_FX_up weight over NAV None
# 105b_SCR_Mrkt_FX_down weight over NAV None
# 106_Asset pledged as collateral None
# 107_Place of deposit None
# 108_Participation None
# 110_Valorisation method None
# 111_Value of acquisition None
# 112_Credit rating None
# 113_Rating agency None
# 114_Issuer economic area None
# 115_Fund Issuer Code None
# 116_Fund Issuer Code Type None
# 117_Fund Issuer Name None
# 118_Fund Issuer Sector None
# 119_Fund Issuer Group Code None
# 120_Fund Issuer Group Code Type None
# 121_Fund Issuer Group name None
# 122_Fund Issuer Country None
# 123_Fund CIC code None
# 123a_Fund Custodian Country None
# 124_Duration None
# 125_Accrued Income (Security Denominated Currency) None
# 126_Accrued Income (Portfolio Denominated Currency) None
# 127_Bond Floor (convertible instrument only) None
# 128_Option premium (convertible instrument only) None
# 129_Valuation Yield None
# 130_Valuation Z-spread None
# 131_Underlying Asset Category None
# 132_Infrastructure_investment None
# 133_custodian_name None
# 134_type1_private_equity_portfolio_eligibility None
# 135_type1_private_equity_issuer_beta None
# 137_counterparty_sector None
# 1000_TPT Version None

# %% [markdown]
# ### Create TPT dataframe

# %%
TPT_report = pd.DataFrame(columns=fields)
#TPT_report
report.columns.difference(TPT_report.columns)
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## 1 - Find all instruments associated to a shareclass

# %% [markdown]
# ### 1.1 Get infos of the shareclass from database

# %%
shareclass_infos = pd.read_sql_query("SELECT id, code_isin, shareclass, shareclass_currency, shareclass_name, id_subfund, type_tpt " +
                                     "FROM intranet.dbo.shareclass " +
                                     "WHERE code_isin='%s'"%ISIN, connector)
shareclass_infos["id"]
# Out:
# 0    25
# Name: id, dtype: int64

# %%
shareclass_nav = pd.read_sql_query("SELECT shareclass_total_net_asset, "+
                                           "nav_date, "+
                                           "share_price, "+
                                           "outstanding_shares "+
                                   " FROM intranet.dbo.nav " +
                                   "WHERE id_shareclass='%s' "%shareclass_infos["id"].iloc[0] +
                                   "AND nav_date='%s'"%DATE,
                                   connector)
shareclass_nav
# Out:
#    shareclass_total_net_asset    nav_date  share_price  outstanding_shares
# 0                 11791377.12  2020-12-31       183.95           64100.413

# %% [markdown]
# ### 1.2 Get infos of the subfund the shareclass belongs to

# %%
subfund_id = shareclass_infos["id_subfund"].iloc[0]
subfund_infos = pd.read_sql_query("SELECT * " +
                                  "FROM intranet.dbo.subfund " +
                                  "WHERE id='%s'"%subfund_id, connector)
subfund_infos
# Out:
#    id last_update  supprime fund_cic_code      fund_issuer_code  \
# 0  10  2020-12-18     False          XL42  549300BQB9WT2XT2WB26
#
#   fund_issuer_code_type fund_issuer_sector subfund_code subfund_currency  \
# 0                     1              K6430   bil_LU3964              USD
#
#                                       subfund_name subfund_type valuation_day  \
# 0  BIL Invest Bonds USD Corporate Investment Grade         None             5
#
#    id_fund
# 0       10

# %% [markdown]
# ### 1.3 Get portfolio of the subfund
#
# /!\ /!\ /!\ until portfolios are put in database, infos must be read from excel sheets /!\ /!\ /!\

# %%
#portfolio = pd.read_sql_query("SELECT * " +
#                              "FROM intranet.dbo.portfolio " +
#                              "WHERE subfund_id='%s'"%subfund_id, connector)

# %% [markdown]
# #### Loading required datas

# %%
# loading portfolio's data
portfolio = pd.read_excel(portfolio_file_path, sheet_name="bil_invest_portfolio")
NAV = pd.read_excel(portfolio_file_path, sheet_name="NAV")
TPT_base = pd.read_excel(portfolio_file_path, sheet_name="TPT BIL Invest")

# %% [markdown]
# ### 1.4 Find all instruments associated to subfund

# %%
# get subfund code from database and remove prefix
subfund_code = subfund_infos["subfund_code"].iloc[0].split("_")[1]
# get all entries with corresponding subfund code
entries = TPT_base.loc[TPT_base["SubFund Code"] == subfund_code]
entries.shape
#entries.info()
# Out:
# (167, 65)

# %% [markdown]
# ### 1.5 Query instruments' infos from db

# %% [markdown]
# /!\ /!\ /!\ until instruments are put in database, infos must be read from excel sheets /!\ /!\ /!\

# %%
#instruments_infos = pd.read_sql_query("SELECT * FROM intranet.dbo.instrument", connector)
#instruments_infos

# %%
AODB = pd.read_excel(AODB_file_path, sheet_name="DataBase")
AODB
# Out:
#            # 14_Identification code of the financial instrument  \
# 0     BBG ID                                                NaN
# 1        fix                                                fix
# 2          1                                       DE000A18V138
# 3          2                                       DE000A1MA9K8
# 4          3                                       DE000A1X3GC3
# ...      ...                                                ...
# 3895    3895                                       US8807791038
# 3896    3896                                       US2774321002
# 3897    3897                                       US9113121068
# 3898    3898                                       US4062161017
# 3899    3899                                       US5745991068
#
#           BBG Ticker 12_CIC code of the instrument  \
# 0              DX615                         DZ547
# 1                fix                           fix
# 2     JV2247650 Corp                          DE21
# 3     EJ0400550 Corp                          DE21
# 4     EJ9325857 Corp                          DE21
# ...              ...                           ...
# 3895   TEX UN Equity                          US31
# 3896   EMN UN Equity                          US31
# 3897   UPS UN Equity                          US31
# 3898   HAL UN Equity                          US31
# 3899   MAS UN Equity                          US31
#
#      13_Economic zone of the quotation place  \
# 0                                        NaN
# 1                                        fix
# 2                                          1
# 3                                          1
# 4                                          1
# ...                                      ...
# 3895                                       2
# 3896                                       2
# 3897                                       2
# 3898                                       2
# 3899                                       2
#
#      14_Identification code of the financial instrument.1  \
# 0                                                   NaN
# 1                                                   fix
# 2                                          DE000A18V138
# 3                                          DE000A1MA9K8
# 4                                          DE000A1X3GC3
# ...                                                 ...
# 3895                                       US8807791038
# 3896                                       US2774321002
# 3897                                       US9113121068
# 3898                                       US4062161017
# 3899                                       US5745991068
#
#      15_Type of identification code for the instrument  \
# 0                                                  NaN
# 1                                                  fix
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ...                                                ...
# 3895                                                 1
# 3896                                                 1
# 3897                                                 1
# 3898                                                 1
# 3899                                                 1
#
#              17_Instrument name 17b_Asset / Liability  \
# 0                           NaN                   NaN
# 1                           fix                   fix
# 2             VONOVIA 1.625% 20                     A
# 3               METRO 3.375% 19                     A
# 4             DAIMLER 1.500% 18                     A
# ...                         ...                   ...
# 3895                 Terex Corp                     A
# 3896        Eastman Chemical Co                     A
# 3897  United Parcel Service Inc                     A
# 3898             Halliburton Co                     A
# 3899                 Masco Corp                     A
#
#      20_Contract size for derivatives  ... SECURITY_TYP_UNDERLYING  \
# 0                                 NaN  ...                   DS213
# 1                                 fix  ...                     fix
# 2                                 NaN  ...                     NaN
# 3                                 NaN  ...                     NaN
# 4                                 NaN  ...                     NaN
# ...                               ...  ...                     ...
# 3895                              NaN  ...                     NaN
# 3896                              NaN  ...                     NaN
# 3897                              NaN  ...                     NaN
# 3898                              NaN  ...                     NaN
# 3899                              NaN  ...                     NaN
#
#      89_Credit quality step of the underlying asset Dynasty SICAV Quilvest  \
# 0                                               NaN           yes      yes
# 1                                          variable           yes      yes
# 2                                               NaN            no       no
# 3                                               NaN            no       no
# 4                                               NaN            no       no
# ...                                             ...           ...      ...
# 3895                                            NaN            no       no
# 3896                                            NaN            no       no
# 3897                                            NaN            no       no
# 3898                                            NaN            no       no
# 3899                                            NaN            no       no
#
#      den-am Athymis  BIL Pictet update required ?  UPD
# 0       yes     yes  yes    yes               yes  yes
# 1       yes     yes  yes    yes               yes  yes
# 2        no      no   no     no                no   no
# 3        no      no   no     no                no   no
# 4        no      no   no     no                no   no
# ...     ...     ...  ...    ...               ...  ...
# 3895     no      no   no    yes               yes   no
# 3896     no      no   no    yes               yes   no
# 3897     no      no   no    yes               yes   no
# 3898     no      no   no    yes               yes   no
# 3899     no      no   no    yes               yes   no
#
# [3900 rows x 77 columns]

# %% [markdown]
# ### 1.6 drop entries associated to other shareclasses

# %%
# get shareclass indicator
sc_indicator = shareclass_infos["shareclass"].iloc[0]

entries = entries.loc[(entries["SC indicator"].isnull()) | (entries["SC indicator"] == sc_indicator)]
entries
#entries["Valuation Label"]
# Out:
#       NAV Date SubFund Code                         SubFund Name  \
# 191 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 192 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 197 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 201 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 203 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# ..         ...          ...                                  ...
# 351 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 352 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 353 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 354 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
# 355 2020-12-31       LU3964  BIL INVEST BDS USD CORP INVMT GRADE
#
#     SubFund Currency Portfolio Accounting Service Code  \
# 191              USD      CASH                      CO
# 192              USD      CASH                      CO
# 197              USD      CASH                      CO
# 201              USD      CASH                      CO
# 203              USD      CASH                      CO
# ..               ...       ...                     ...
# 351              USD  SECURITY                      BO
# 352              USD  SECURITY                      BO
# 353              USD  SECURITY                      BO
# 354              USD  SECURITY                      BO
# 355              USD  SECURITY                      BO
#
#     Accounting Service Name  Valuation Group Code Valuation Group Label  \
# 191          Debits/credits                   850          ACCRUED EXP.
# 192          Debits/credits                   850          ACCRUED EXP.
# 197          Debits/credits                   800              PAYABLES
# 201          Debits/credits                   850          ACCRUED EXP.
# 203          Debits/credits                   600           RECEIVABLES
# ..                      ...                   ...                   ...
# 351            Stock market                   150                 BONDS
# 352            Stock market                   150                 BONDS
# 353            Stock market                   150                 BONDS
# 354            Stock market                   150                 BONDS
# 355            Stock market                   150                 BONDS
#
#      GTI Code  ... Net Nav Amount  % impact     Unique ID  Multiple Leg ID  \
# 191       NaN  ...    75455236.11 -0.002087      294864_1              NaN
# 192       NaN  ...    75455236.11 -0.003356      290034_1              NaN
# 197       NaN  ...    75455236.11 -0.311661      266100_1              NaN
# 201       NaN  ...    75455236.11 -0.015254      264287_1              NaN
# 203       NaN  ...    75455236.11 -0.000007      152001_1              NaN
# ..        ...  ...            ...       ...           ...              ...
# 351     201.0  ...    75455236.11  0.358816  US60687YBC21              NaN
# 352     201.0  ...    75455236.11  0.497346  US42824CBD02              NaN
# 353     201.0  ...    75455236.11  0.266603  US60687YBB48              NaN
# 354     220.0  ...    75455236.11  1.022893  US912810SP49              NaN
# 355     220.0  ...    75455236.11  0.212055  US91282CBD20              NaN
#
#      Quantity.1  MV inv_ccy MV fnd_ccy SC indicator LU1689729546  \
# 191    -1574.74    -1574.74   -1574.74            P          NaN
# 192    -2532.17    -2532.17   -2532.17            P          NaN
# 197  -235164.32  -235164.32 -235164.32          NaN          NaN
# 201   -11509.91   -11509.91  -11509.91            P          NaN
# 203       -5.04       -5.04      -5.04          NaN          NaN
# ..          ...         ...        ...          ...          ...
# 351   270000.00   271002.42  271002.42          NaN          NaN
# 352   375000.00   375479.89  375479.89          NaN          NaN
# 353   200000.00   201296.88  201296.88          NaN          NaN
# 354   825000.00   776270.44  776270.44          NaN          NaN
# 355   160000.00   160009.01  160009.01          NaN          NaN
#
#     Accred expenses splitted
# 191                      NaN
# 192                      NaN
# 197                      NaN
# 201                      NaN
# 203                      NaN
# ..                       ...
# 351                      NaN
# 352                      NaN
# 353                      NaN
# 354                      NaN
# 355                      NaN
#
# [156 rows x 65 columns]

# %% [markdown]
# #### We get 156 instruments associated to the shareclass LU1689732417 which is the expected result

# %% [markdown]
# ###  1.7 Get infos from db

# %%
instruments_infos_raw = AODB.loc[AODB["14_Identification code of the financial instrument"].isin(entries["Unique ID"])]
#instruments_infos_raw.info()
instruments_infos_raw.shape
instruments_infos_raw["17_Instrument name"]
# Out:
# 2476       SCHLUMBER 3.75% 19-01.05.24
# 2479        AT&T INC 4.85% 19-01.03.39
# 2480        WESTROCK 3.75% 18-15.03.25
# 2482    GE CAP INTL 4.418% 16-15.11.35
# 2488           BOEING 3.1% 19-01.05.26
#                      ...
# 3493               NSCCLF 0 ¾ 12/07/25
# 3494             SOCGEN 1.488 12/14/26
# 3495                 STLD 3 ¼ 10/15/50
# 3496                    T 1 ⅜ 08/15/50
# 3658                    T 0 ⅛ 12/31/22
# Name: 17_Instrument name, Length: 149, dtype: object

# %% [markdown]
# ### 1.8 Build instruments infos

# %%
#"16_Grouping code for multiple leg instruments"
#"17b_Asset / Liability",
instruments_infos_list = ["12_CIC code of the instrument",
                          "13_Economic zone of the quotation place",
                          "14_Identification code of the financial instrument",
                          "15_Type of identification code for the instrument",
                          "17_Instrument name",
                          "20_Contract size for derivatives", 
                          "21_Quotation currency (A)",
                          "32_Interest rate type",
                          "33_Coupon rate",
                          "34_Interest rate reference identification",
                          "35_Identification type for interest rate index",
                          "36_Interest rate index name",
                          "37_Interest rate Margin",
                          "38_Coupon payment frequency",
                          "39_Maturity date",
                          "40_Redemption type",
                          "41_Redemption rate",
                          "42_Callable / putable",
                          "43_Call / put date",
                          "44_Issuer / bearer option exercise",
                          "45_Strike price for embedded (call/put) options",
                          "46_Issuer name",
                          "47_Issuer identification code",
                          "49_Name of the group of the issuer",
                          "50_Identification of the group",
                          "52_Issuer country",
                          "53_Issuer economic area",
                          "54_Economic sector",
                          "55_Covered / not covered",
                          "56_Securitisation",
                          "57_Explicit guarantee by the country of issue",
                          "58_Subordinated debt",
                          "58b_Nature of the TRANCHE",
                          "59_Credit quality step",
                          "60_Call / Put / Cap / Floor",
                          "61_Strike price",
                          "62_Conversion factor (convertibles)/ concordance factor/ parity (options)",
                          "63_Effective Date of Instrument",
                          "64_Exercise type",
                          "67_CIC code of the underlying asset",
                          "68_Identification code of the underlying asset",
                          "69_Type of identification code for the underlying asset",
                          "70_Name of the underlying asset",
                          "71_Quotation currency of the underlying asset ( C )",
                          "72_Last valuation price of the underlying asset",
                          "73_Country of quotation of the underlying asset",
                          "74_Economic Area of quotation of the underlying asset",
                          "75_Coupon rate of the underlying asset",
                          "76_Coupon payment frequency of the underlying asset",
                          "77_Maturity date of the underlying asset",
                          "78_Redemption profile of the underlying asset",
                          "79_Redemption rate of the underlying asset",
                          "80_Issuer name of the underlying asset",
                          "81_Issuer identification code of the underlying asset",
                          "82_Type of issuer identification code of the underlying asset",
                          "83_Name of the group of the issuer of the underlying asset",
                          "84_Identification of the group of the underlying asset",
                          "85_Type of the group identification code of the underlying asset",
                          "86_Issuer country of the underlying asset",
                          "87_Issuer economic area of the underlying asset",
                          "88_Explicit guarantee by the country of issue of the underlying asset",
                          "89_Credit quality step of the underlying asset"]

#instruments_infos = pd.DataFrame(columns=instruments_infos_list)

instruments_infos_raw['12_CIC code of the instrument']
# Out:
# 2476    XL21
# 2479    US21
# 2480    CA21
# 2482    US21
# 2488    US21
#         ...
# 3493    XL21
# 3494    XL21
# 3495    DE21
# 3496    US11
# 3658    US11
# Name: 12_CIC code of the instrument, Length: 149, dtype: object

# %%
instruments_db_infos = instruments_infos_raw[instruments_infos_list]
#instruments_db_infos.merge(instruments_infos_raw)
instruments_db_infos
# Out:
#      12_CIC code of the instrument 13_Economic zone of the quotation place  \
# 2476                          XL21                                       0
# 2479                          US21                                       2
# 2480                          CA21                                       2
# 2482                          US21                                       2
# 2488                          US21                                       2
# ...                            ...                                     ...
# 3493                          XL21                                       0
# 3494                          XL21                                       0
# 3495                          DE21                                       1
# 3496                          US11                                       2
# 3658                          US11                                       2
#
#      14_Identification code of the financial instrument  \
# 2476                                       US806851AJ09
# 2479                                       US00206RHK14
# 2480                                       US96145DAF24
# 2482                                       US36164QNA21
# 2488                                       US097023CH65
# ...                                                 ...
# 3493                                       US637639AE51
# 3494                                       US83368RAZ55
# 3495                                       US858119BP41
# 3496                                       US912810SP49
# 3658                                       US91282CBD20
#
#      15_Type of identification code for the instrument  \
# 2476                                                 1
# 2479                                                 1
# 2480                                                 1
# 2482                                                 1
# 2488                                                 1
# ...                                                ...
# 3493                                                 1
# 3494                                                 1
# 3495                                                 1
# 3496                                                 1
# 3658                                                 1
#
#                   17_Instrument name 20_Contract size for derivatives  \
# 2476     SCHLUMBER 3.75% 19-01.05.24                              NaN
# 2479      AT&T INC 4.85% 19-01.03.39                              NaN
# 2480      WESTROCK 3.75% 18-15.03.25                              NaN
# 2482  GE CAP INTL 4.418% 16-15.11.35                              NaN
# 2488         BOEING 3.1% 19-01.05.26                              NaN
# ...                              ...                              ...
# 3493             NSCCLF 0 ¾ 12/07/25                              NaN
# 3494           SOCGEN 1.488 12/14/26                              NaN
# 3495               STLD 3 ¼ 10/15/50                              NaN
# 3496                  T 1 ⅜ 08/15/50                              NaN
# 3658                  T 0 ⅛ 12/31/22                              NaN
#
#      21_Quotation currency (A) 32_Interest rate type 33_Coupon rate  \
# 2476                       USD                 FIXED           3.75
# 2479                       USD                 FIXED           4.85
# 2480                       USD                 FIXED           3.75
# 2482                       USD                 FIXED          4.418
# 2488                       USD                 FIXED            3.1
# ...                        ...                   ...            ...
# 3493                       USD                 FIXED           0.75
# 3494                       USD              VARIABLE          1.488
# 3495                       USD                 FIXED           3.25
# 3496                       USD                 FIXED          1.375
# 3658                       USD                 FIXED          0.125
#
#      34_Interest rate reference identification  ...  \
# 2476                                       NaN  ...
# 2479                                       NaN  ...
# 2480                                       NaN  ...
# 2482                                       NaN  ...
# 2488                                       NaN  ...
# ...                                        ...  ...
# 3493                                       NaN  ...
# 3494                                       NaN  ...
# 3495                                       NaN  ...
# 3496                                       NaN  ...
# 3658                                       NaN  ...
#
#      80_Issuer name of the underlying asset  \
# 2476                                    NaN
# 2479                                    NaN
# 2480                                    NaN
# 2482                                    NaN
# 2488                                    NaN
# ...                                     ...
# 3493                                    NaN
# 3494                                    NaN
# 3495                                    NaN
# 3496                                    NaN
# 3658                                    NaN
#
#      81_Issuer identification code of the underlying asset  \
# 2476                                                NaN
# 2479                                                NaN
# 2480                                                NaN
# 2482                                                NaN
# 2488                                                NaN
# ...                                                 ...
# 3493                                                NaN
# 3494                                                NaN
# 3495                                                NaN
# 3496                                                NaN
# 3658                                                NaN
#
#      82_Type of issuer identification code of the underlying asset  \
# 2476                                                NaN
# 2479                                                NaN
# 2480                                                NaN
# 2482                                                NaN
# 2488                                                NaN
# ...                                                 ...
# 3493                                                NaN
# 3494                                                NaN
# 3495                                                NaN
# 3496                                                NaN
# 3658                                                NaN
#
#      83_Name of the group of the issuer of the underlying asset  \
# 2476                                                NaN
# 2479                                                NaN
# 2480                                                NaN
# 2482                                                NaN
# 2488                                                NaN
# ...                                                 ...
# 3493                                                NaN
# 3494                                                NaN
# 3495                                                NaN
# 3496                                                NaN
# 3658                                                NaN
#
#      84_Identification of the group of the underlying asset  \
# 2476                                                NaN
# 2479                                                NaN
# 2480                                                NaN
# 2482                                                NaN
# 2488                                                NaN
# ...                                                 ...
# 3493                                                NaN
# 3494                                                NaN
# 3495                                                NaN
# 3496                                                NaN
# 3658                                                NaN
#
#      85_Type of the group identification code of the underlying asset  \
# 2476                                                NaN
# 2479                                                NaN
# 2480                                                NaN
# 2482                                                NaN
# 2488                                                NaN
# ...                                                 ...
# 3493                                                NaN
# 3494                                                NaN
# 3495                                                NaN
# 3496                                                NaN
# 3658                                                NaN
#
#      86_Issuer country of the underlying asset  \
# 2476                                       NaN
# 2479                                       NaN
# 2480                                       NaN
# 2482                                       NaN
# 2488                                       NaN
# ...                                        ...
# 3493                                       NaN
# 3494                                       NaN
# 3495                                       NaN
# 3496                                       NaN
# 3658                                       NaN
#
#      87_Issuer economic area of the underlying asset  \
# 2476                                             NaN
# 2479                                             NaN
# 2480                                             NaN
# 2482                                             NaN
# 2488                                             NaN
# ...                                              ...
# 3493                                             NaN
# 3494                                             NaN
# 3495                                             NaN
# 3496                                             NaN
# 3658                                             NaN
#
#      88_Explicit guarantee by the country of issue of the underlying asset  \
# 2476                                                NaN
# 2479                                                NaN
# 2480                                                NaN
# 2482                                                NaN
# 2488                                                NaN
# ...                                                 ...
# 3493                                                NaN
# 3494                                                NaN
# 3495                                                NaN
# 3496                                                NaN
# 3658                                                NaN
#
#      89_Credit quality step of the underlying asset
# 2476                                            NaN
# 2479                                            NaN
# 2480                                            NaN
# 2482                                            NaN
# 2488                                            NaN
# ...                                             ...
# 3493                                            NaN
# 3494                                            NaN
# 3495                                            NaN
# 3496                                            NaN
# 3658                                            NaN
#
# [149 rows x 62 columns]

# %%
instruments_infos["17_Instrument name"] = entries["Valuation Label"]
test = entries.rename(columns={"Valuation Label" : "17_Instrument name",
                        "Unique ID" : "14_Identification code of the financial instrument"})
test = test.loc[:,["17_Instrument name", "14_Identification code of the financial instrument", "Valuation Group Label"]].set_index(["17_Instrument name"])
#test = instruments_infos.merge(entries, left_on=["17_Instrument name"], right_on=["Valuation Label"]) 
#instruments_infos["14_Identification code of the financial instrument"] = entries["Unique ID"]

#test[["14_Identification code of the financial instrument", "17_Instrument name"]]

#test = instruments_infos.loc[:,["17_Instrument name", "14_Identification code of the financial instrument"]].merge(entries.loc[:,["Valuation Label", "Unique ID"]], left_on=["17_Instrument name"], right_on=["Valuation Label"])
instruments_infos.set_index(["17_Instrument name"], inplace=True)
instruments_infos
#instruments_infos.loc[["ADVANCE AUT 1.75% 20-01.10.27"], "14_Identification code of the financial instrument"].update(test["14_Identification code of the financial instrument"])
#instruments_infos.loc["ADVANCE AUT 1.75% 20-01.10.27", "14_Identification code of the financial instrument"]
#test.set_index(["17_Instrument name"])

#instruments_infos.reset_index(inplace=True)
#instruments_infos
#test
#test[]
#idn = "14_Identification code of the financial instrument"
#fields = instruments_infos_list[:3]
#instruments_infos.loc[instruments_infos[idn].isin(instruments_infos_raw[idn]), fields] = instruments_infos_raw[fields]

#instruments_infos[instruments_infos_list[:10]]
#for field in instruments_infos_list:
#    if field not in ['16_Grouping code for multiple leg instruments',
#                     '17_Instrument name',
#                     '14_Identification code of the financial instrument']:
#        instruments_infos.loc[
#            instruments_infos[idn].isin(
#                instruments_infos_raw[idn]),
#            field] = instruments_infos_raw[field].to_numpy()
#instruments_infos
# Out:
#                    12_CIC code of the instrument  \
# 17_Instrument name
# NaN                                         XT72
# NaN                                         XT72
# NaN                                         XT72
# NaN                                         XT72
# NaN                                         XT72
# ...                                          ...
# NaN                                          NaN
# NaN                                          NaN
# NaN                                          NaN
# NaN                                          NaN
# NaN                                          NaN
#
#                    13_Economic zone of the quotation place  \
# 17_Instrument name
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
# ...                                                    ...
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
#
#                    14_Identification code of the financial instrument  \
# 17_Instrument name
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                    15_Type of identification code for the instrument  \
# 17_Instrument name
# NaN                                                              NaN
# NaN                                                              NaN
# NaN                                                              NaN
# NaN                                                              NaN
# NaN                                                              NaN
# ...                                                              ...
# NaN                                                              NaN
# NaN                                                              NaN
# NaN                                                              NaN
# NaN                                                              NaN
# NaN                                                              NaN
#
#                    16_Grouping code for multiple leg instruments  \
# 17_Instrument name
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# ...                                                          ...
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                    17b_Asset / Liability 20_Contract size for derivatives  \
# 17_Instrument name
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
# ...                                  ...                              ...
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
# NaN                                  NaN                              NaN
#
#                    21_Quotation currency (A) 32_Interest rate type  \
# 17_Instrument name
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
# ...                                      ...                   ...
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
# NaN                                      NaN                   NaN
#
#                    33_Coupon rate  ... 80_Issuer name of the underlying asset  \
# 17_Instrument name                 ...
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
# ...                           ...  ...                                    ...
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
# NaN                           NaN  ...                                    NaN
#
#                    81_Issuer identification code of the underlying asset  \
# 17_Instrument name
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                    82_Type of issuer identification code of the underlying asset  \
# 17_Instrument name
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                    83_Name of the group of the issuer of the underlying asset  \
# 17_Instrument name
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                    84_Identification of the group of the underlying asset  \
# 17_Instrument name
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                    85_Type of the group identification code of the underlying asset  \
# 17_Instrument name
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                    86_Issuer country of the underlying asset  \
# 17_Instrument name
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# ...                                                      ...
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
#
#                    87_Issuer economic area of the underlying asset  \
# 17_Instrument name
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
# ...                                                            ...
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
#
#                    88_Explicit guarantee by the country of issue of the underlying asset  \
# 17_Instrument name
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                    89_Credit quality step of the underlying asset
# 17_Instrument name
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# ...                                                           ...
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
#
# [156 rows x 63 columns]

# %%
idx = test.index[test["Valuation Group Label"] == "ACCRUED EXP."].to_list()
idx += test.index[test["Valuation Group Label"] == "CASH"].to_list()
idx += test.index[test["Valuation Group Label"] == "F.E.T."].to_list()
idx += test.index[test["Valuation Group Label"] == "RECEIVABLES"].to_list()
idx += test.index[test["Valuation Group Label"] == "PAYABLES"].to_list()
instruments_infos.loc[idx, "12_CIC code of the instrument"] = "XT72"
frais = instruments_infos.loc[idx, "12_CIC code of the instrument"]
frais
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-d74c0a99c60f> in <module>
#       4 idx += test.index[test["Valuation Group Label"] == "RECEIVABLES"].to_list()
#       5 idx += test.index[test["Valuation Group Label"] == "PAYABLES"].to_list()
# ----> 6 instruments_infos.loc[idx, "12_CIC code of the instrument"] = "XT72"
#       7 frais = instruments_infos.loc[idx, "12_CIC code of the instrument"]
#       8 frais
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     664         else:
#     665             key = com.apply_if_callable(key, self.obj)
# --> 666         indexer = self._get_setitem_indexer(key)
#     667         self._has_valid_setitem_indexer(key)
#     668
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     607         if isinstance(key, tuple):
#     608             try:
# --> 609                 return self._convert_tuple(key, is_setter=True)
#     610             except IndexingError:
#     611                 pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_tuple(self, key, is_setter)
#     732                 if i >= self.ndim:
#     733                     raise IndexingError("Too many indexers")
# --> 734                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     735                 keyidx.append(idx)
#     736         return tuple(keyidx)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, key, axis, is_setter)
#    1196             else:
#    1197                 # When setting, missing keys are not allowed, even with .loc:
# -> 1198                 return self._get_listlike_indexer(key, axis, raise_missing=True)[1]
#    1199         else:
#    1200             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Subscription Tax P', 'Fixed Servicing Fee P', 'Management Fee P',\n       'C.B. Call Deposits RBC IS Bank Luxbg', 'Int.Rec.Bank Accounts',\n       'Receivable Interests on Bonds', 'Payable on Purchases'],\n      dtype='object', name='17_Instrument name')] are in the [index]"

# %%
CIC_instruments_in_db = instruments_infos_raw[['17_Instrument name', '12_CIC code of the instrument']]
CIC_instruments_in_db.set_index("17_Instrument name", inplace=True)
CIC_instruments_in_db
# Out:
#                                12_CIC code of the instrument
# 17_Instrument name
# SCHLUMBER 3.75% 19-01.05.24                             XL21
# AT&T INC 4.85% 19-01.03.39                              US21
# WESTROCK 3.75% 18-15.03.25                              CA21
# GE CAP INTL 4.418% 16-15.11.35                          US21
# BOEING 3.1% 19-01.05.26                                 US21
# ...                                                      ...
# NSCCLF 0 ¾ 12/07/25                                     XL21
# SOCGEN 1.488 12/14/26                                   XL21
# STLD 3 ¼ 10/15/50                                       DE21
# T 1 ⅜ 08/15/50                                          US11
# T 0 ⅛ 12/31/22                                          US11
#
# [149 rows x 1 columns]

# %%
all_CIC = frais.to_frame().append(CIC_instruments_in_db)
all_CIC
# Out:
#                                      12_CIC code of the instrument
# 17_Instrument name
# Subscription Tax P                                            XT72
# Fixed Servicing Fee P                                         XT72
# Management Fee P                                              XT72
# C.B. Call Deposits RBC IS Bank Luxbg                          XT72
# Int.Rec.Bank Accounts                                         XT72
# ...                                                            ...
# NSCCLF 0 ¾ 12/07/25                                           XL21
# SOCGEN 1.488 12/14/26                                         XL21
# STLD 3 ¼ 10/15/50                                             DE21
# T 1 ⅜ 08/15/50                                                US11
# T 0 ⅛ 12/31/22                                                US11
#
# [156 rows x 1 columns]

# %%
instruments_CIC = instruments_infos["12_CIC code of the instrument"]
instruments_CIC = instruments_CIC.to_frame()
instruments_CIC.merge(CIC_instruments_in_db, how='right', on="17_Instrument name", left_index=True, right_index=True)
instruments_CIC
# Out:
#                             12_CIC code of the instrument
# 17_Instrument name
# Subscription Tax P                                   XT72
# Fixed Servicing Fee P                                XT72
# Payable on Purchases                                  NaN
# Management Fee P                                     XT72
# Int.Rec.Bank Accounts                                 NaN
# ...                                                   ...
# MIZU FIN FRN 20-25.05.24                              NaN
# HP ENTERPRI FRN 19-12.03.21                           NaN
# MIZU FIN FRN 19-13.09.23                              NaN
# USA 1.375% 20-15.08.50 /TBO                           NaN
# USA 0.125% 20-31.12.22 /TBO                           NaN
#
# [156 rows x 1 columns]

# %% [markdown]
# ## 2 - Fill infos of the instruments

# %% [markdown]
# ### 1.1 Fill instruments' infos

# %%
for field in instruments_infos_list:
    TPT_report[field] = instruments_infos[field]
#TPT_report.iloc[:10, 10:20]
# Out:
#     10_Portfolio Modified Duration 11_Complete SCR Delivery  \
# 191                            NaN                      NaN
# 192                            NaN                      NaN
# 197                            NaN                      NaN
# 201                            NaN                      NaN
# 203                            NaN                      NaN
# 204                            NaN                      NaN
# 206                            NaN                      NaN
# 207                            NaN                      NaN
# 208                            NaN                      NaN
# 209                            NaN                      NaN
#
#     12_CIC code of the instrument 13_Economic zone of the quotation place  \
# 191                           NaN                                     NaN
# 192                           NaN                                     NaN
# 197                           NaN                                     NaN
# 201                           NaN                                     NaN
# 203                           NaN                                     NaN
# 204                           NaN                                     NaN
# 206                           NaN                                     NaN
# 207                          XL21                                       0
# 208                          US21                                       2
# 209                          CA21                                       2
#
#     14_Identification code of the financial instrument  \
# 191                                           294864_1
# 192                                           290034_1
# 197                                           266100_1
# 201                                           264287_1
# 203                                           152001_1
# 204                                           151301_1
# 206                                           144120_1
# 207                                       US90351DAB38
# 208                                       US49446RAV15
# 209                                       US38141EC311
#
#     15_Type of identification code for the instrument  \
# 191                                               NaN
# 192                                               NaN
# 197                                               NaN
# 201                                               NaN
# 203                                               NaN
# 204                                               NaN
# 206                                               NaN
# 207                                                 1
# 208                                                 1
# 209                                                 1
#
#     16_Grouping code for multiple leg instruments  \
# 191                                           NaN
# 192                                           NaN
# 197                                           NaN
# 201                                           NaN
# 203                                           NaN
# 204                                           NaN
# 206                                           NaN
# 207                                           NaN
# 208                                           NaN
# 209                                           NaN
#
#                        17_Instrument name 17b_Asset / Liability 18_Quantity
# 191                    Subscription Tax P                   NaN         NaN
# 192                 Fixed Servicing Fee P                   NaN         NaN
# 197                  Payable on Purchases                   NaN         NaN
# 201                      Management Fee P                   NaN         NaN
# 203                 Int.Rec.Bank Accounts                   NaN         NaN
# 204         Receivable Interests on Bonds                   NaN         NaN
# 206  C.B. Call Deposits RBC IS Bank Luxbg                   NaN         NaN
# 207       UBS GRP 4.125% 15-24.09.25 144A                     A         NaN
# 208         KIMCO REALT 3.70% 19-01.10.49                     A         NaN
# 209                   GS 4.8% 14-08.07.44                     A         NaN

# %% [markdown]
# ## 3 - Fill infos of the shareclass

# %% [markdown]
# ### 3.1 Constant infos

# %%
TPT_report["1_Portfolio identifying data"] = ISIN
TPT_report["2_Type of identification code for the fund share or portfolio"] = shareclass_infos["type_tpt"].iloc[0]
TPT_report["3_Portfolio name"] = shareclass_infos["shareclass_name"].iloc[0]
TPT_report["4_Portfolio currency ( B )"] = shareclass_infos["shareclass_currency"].iloc[0]

# %% [markdown]
# ### 3.2 NAV infos

# %%
TPT_report["5_Net asset valuation of the portfolio or the share class in portfolio currency"] = shareclass_nav["shareclass_total_net_asset"].iloc[0]
TPT_report["6_Valuation date"] = shareclass_nav["nav_date"].iloc[0]
TPT_report["7_Reporting date"] = DATE
TPT_report["8_Share price"] = shareclass_nav["share_price"].iloc[0]
TPT_report["8b_Total number of shares"] = shareclass_nav["outstanding_shares"].iloc[0]
#TPT_report

# %% [markdown]
# ## 4 - Fill fund & subfund infos

# %% [markdown]
# ###  4.1 subfund infos

# %%
TPT_report["115_Fund Issuer Code"] = subfund_infos["fund_issuer_code"].iloc[0]
TPT_report["116_Fund Issuer Code Type"] = subfund_infos["fund_issuer_code_type"].iloc[0] 
TPT_report["117_Fund Issuer Name"] = subfund_infos["subfund_name"].iloc[0]
TPT_report["118_Fund Issuer Sector"] = subfund_infos["fund_issuer_sector"].iloc[0] 
TPT_report["123_Fund CIC code "] = subfund_infos["fund_cic_code"].iloc[0]
# subfund_code subfund_currency

# %% [markdown]
# ### 4.2 fund infos

# %%
# get infos of fund from db
fund_id = subfund_infos["id_fund"].iloc[0]
fund_infos = pd.read_sql_query("SELECT * " +
                                  "FROM intranet.dbo.fund " +
                                  "WHERE id='%s'"%fund_id, connector)
fund_infos
# Out:
#    id last_update  supprime  custodian_name fund_code fund_currency  \
# 0  10  2020-12-18     False  RBC Luxembourg      BIL1           EUR
#
#   fund_custodian_country fund_issuer_country fund_issuer_group_code  \
# 0                     LU                  LU   549300OKO8371SPM7H13
#
#   fund_issuer_group_code_type fund_issuer_group_name   fund_name fund_type  \
# 0                           1             BIL Invest  BIL Invest     UCITS
#
#    id_client
# 0          3

# %%
TPT_report["119_Fund Issuer Group Code"] = fund_infos["fund_issuer_group_code"].iloc[0]
TPT_report["120_Fund Issuer Group Code Type"] = fund_infos["fund_issuer_group_code_type"].iloc[0]
TPT_report["121_Fund Issuer Group name"] = fund_infos["fund_issuer_group_name"].iloc[0]
TPT_report["122_Fund Issuer Country"] = fund_infos["fund_issuer_country"].iloc[0]
TPT_report["123a_Fund Custodian Country"] = fund_infos["fund_custodian_country"].iloc[0]
TPT_report["133_custodian_name"] = fund_infos["custodian_name"].iloc[0]

#TPT_report.iloc[:,125:135]

# %% [markdown]
# ## 4 - Fill Bloomberg infos

# %% [markdown]
# /!\ /!\ /!\ until Bloomberg infos are put in database, infos must be read from excel sheets /!\ /!\ /!\

# %%
#BBG = pd.read_sql_query("SELECT * FROM intranet.dbo.bloomberg", connector)
#BBG

# %%
BBG = pd.read_excel(BBG_file_path, sheet_name="Hard Copy", skiprows=2)
BBG
# Out:
#                       Fund          ISIN         BBG ticker  \
# 0     PLACEURO BG OPPORTU   FR0013153160     JK6295154 Corp
# 1     PLACEURO BG OPPORTU   FR0013489739  FR0013489739 Corp
# 2     PLACEURO BG OPPORTU   XS1562036704     AM3527430 Corp
# 3     PLACEURO BG OPPORTU   XS1600514696  XS1600514696 Corp
# 4     PLACEURO BG OPPORTU   XS2167595672  XS2167595672 Corp
# ...                    ...           ...                ...
# 996                    NaN  XS2138128314  XS2138128314 Corp
# 997                    NaN  XS2178833773  XS2178833773 Corp
# 998                    NaN  XS2187689380  XS2187689380 Corp
# 999                    NaN  XS2198388592  XS2198388592 Corp
# 1000                   NaN  XS2232108568  XS2232108568 Corp
#
#             Instrument name   YAS_RISK YAS_MOD_DUR CV_MODEL_DELTA_S  \
# 0     LAGARDERE 2,75 16-23     2.32445     2.30318                -
# 1       KORIAN 0,875 20-27     3.11847      5.8303           23.199
# 2       MARCOLIN FRN 17-23   0.0388041   0.0425853                -
# 3       BURGERK 6,00 17-24   0.0238275   0.0198265                -
# 4      EUROFINS 3,75 20-26     5.91718     4.92724                -
# ...                     ...        ...         ...              ...
# 996                     NaN    1.39905      1.2641                -
# 997                     NaN    5.05458     4.35226                -
# 998                     NaN    7.85952     7.09712                -
# 999                     NaN    1.59393     1.36661                -
# 1000                    NaN    3.45264     3.23721                -
#
#      DUR_ADJ_MTY_MID      MTY_TYP  credit_sensitivity cv_model_gamma_v  \
# 0             2.3128     CALLABLE                 NaN                -
# 1            6.01875  CONVERTIBLE                 NaN       0.00505712
# 2          0.0440292     CALLABLE                 NaN                -
# 3              3.045     CALLABLE                 NaN                -
# 4              5.212     CALLABLE                 NaN                -
# ...              ...          ...                 ...              ...
# 996          4.98248     CALLABLE                 NaN                -
# 997          4.58681     CALLABLE                 NaN                -
# 998          7.10421    PERP/CALL                 NaN                -
# 999          3.59128     CALLABLE                 NaN                -
# 1000         4.78094     CALLABLE                 NaN                -
#
#      CV_MODEL_vega cv_model_cnvs_prem cv_model_bond_val Unnamed: 14
# 0                -                  -                 -           -
# 1         0.228387            3.02877            49.621     46.5922
# 2                -                  -                 -           -
# 3                -                  -                 -           -
# 4                -                  -                 -           -
# ...            ...                ...               ...         ...
# 996              -                  -                 -           -
# 997              -                  -                 -           -
# 998              -                  -                 -           -
# 999              -                  -                 -           -
# 1000             -                  -                 -           -
#
# [1001 rows x 15 columns]

# %%
instruments_BBG_infos = BBG.loc[BBG["ISIN"].isin(entries["Unique ID"])]
instruments_BBG_infos
# Out:
#     Fund          ISIN         BBG ticker Instrument name  YAS_RISK  \
# 697  NaN  US90351DAB38  US90351DAB38 Corp             NaN   4.98514
# 698  NaN  US49446RAV15  US49446RAV15 Corp             NaN   18.9306
# 699  NaN  US38141EC311  US38141EC311 Corp             NaN   21.3661
# 700  NaN  US49446RAX70  US49446RAX70 Corp             NaN   6.71292
# 701  NaN  US911312BW51  US911312BW51 Corp             NaN    26.718
# ..   ...           ...                ...             ...       ...
# 841  NaN  US60687YBC21  US60687YBC21 Corp             NaN  0.156501
# 842  NaN  US42824CBD02  US42824CBD02 Corp             NaN  0.197453
# 843  NaN  US60687YBB48  US60687YBB48 Corp             NaN  0.208708
# 844  NaN  US912810SP49  US912810SP49 Corp             NaN   22.4108
# 845  NaN  US91282CBD20  US91282CBD20 Corp             NaN   1.99707
#
#     YAS_MOD_DUR CV_MODEL_DELTA_S DUR_ADJ_MTY_MID      MTY_TYP  \
# 697     4.31614                -         4.31149  AT MATURITY
# 698     17.6504                -         17.6289     CALLABLE
# 699      15.156                -         15.1098     CALLABLE
# 700     6.50225                -         6.63674     CALLABLE
# 701     17.3217                -         17.1246     CALLABLE
# ..          ...              ...             ...          ...
# 841    0.155861                -        0.155962     CALLABLE
# 842    0.197121                -        0.197006  AT MATURITY
# 843    0.206846                -        0.206477     CALLABLE
# 844      23.877                -         23.6321       NORMAL
# 845     1.99692                -         1.99663       NORMAL
#
#      credit_sensitivity cv_model_gamma_v CV_MODEL_vega cv_model_cnvs_prem  \
# 697                 NaN                -             -                  -
# 698                 NaN                -             -                  -
# 699                 NaN                -             -                  -
# 700                 NaN                -             -                  -
# 701                 NaN                -             -                  -
# ..                  ...              ...           ...                ...
# 841                 NaN                -             -                  -
# 842                 NaN                -             -                  -
# 843                 NaN                -             -                  -
# 844                 NaN                -             -                  -
# 845                 NaN                -             -                  -
#
#     cv_model_bond_val Unnamed: 14
# 697                 -           -
# 698                 -           -
# 699                 -           -
# 700                 -           -
# 701                 -           -
# ..                ...         ...
# 841                 -           -
# 842                 -           -
# 843                 -           -
# 844                 -           -
# 845                 -           -
#
# [149 rows x 15 columns]

# %%
TPT_report["90_Modified Duration to maturity date"] = instruments_BBG_infos
TPT_report["91_Modified duration to next option exercise date"]
TPT_report["92_Credit sensitivity"]
TPT_report["93_Sensitivity to underlying asset price (delta)"]
TPT_report["94_Convexity / gamma for derivatives"]
TPT_report["94b_Vega"]
TPT_report["127_Bond Floor (convertible instrument only)"]
TPT_report["128_Option premium (convertible instrument only)"]
