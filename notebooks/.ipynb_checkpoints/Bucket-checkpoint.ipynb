# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import pandas as pd
import numpy as np
from pathlib import Path
from TPT_generator_python import Data_Bucket, TPT_Fetcher
from TPT_generator_python.constants import FIELDS

# %%
DATE = "2020-12-31"
CLIENT = "BIL"
ISIN = "LU1689730718"
SOURCE_DIR = Path("../data")

# %%
bucket = Data_Bucket(DATE, CLIENT, ISIN, SOURCE_DIR)

# %%
print(bucket.get_instruments_infos(info=FIELDS["12"], instruments="all"))
# Out:
# 14_Identification code of the financial instrument
# 294880_1        XT79
# 294864_1        XT79
# 290034_1        XT79
# 290018_1        XT79
# 267287_1        XT79
#                 ...
# XS2221845683    DE28
# IE00B3T9LM79    DE42
# LU1663872726    XL42
# LU0144746509    XL42
# LU1373033965    XL42
# Name: 12_CIC code of the instrument, Length: 157, dtype: object

# %%
isins = bucket.get_isins_in_group()
print(isins)
MI = pd.MultiIndex.from_product([bucket.get_instruments(indicator="all").index,
                                 isins], names=["instrument", "shareclass"])
print(MI)
# Out:
# ['LU1689730718', 'LU1689730809', 'LU1689730981']
# MultiIndex([(    '294880_1', 'LU1689730718'),
#             (    '294880_1', 'LU1689730809'),
#             (    '294880_1', 'LU1689730981'),
#             (    '294864_1', 'LU1689730718'),
#             (    '294864_1', 'LU1689730809'),
#             (    '294864_1', 'LU1689730981'),
#             (    '290034_1', 'LU1689730718'),
#             (    '290034_1', 'LU1689730809'),
#             (    '290034_1', 'LU1689730981'),
#             (    '290018_1', 'LU1689730718'),
#             ...
#             ('IE00B3T9LM79', 'LU1689730981'),
#             ('LU1663872726', 'LU1689730718'),
#             ('LU1663872726', 'LU1689730809'),
#             ('LU1663872726', 'LU1689730981'),
#             ('LU0144746509', 'LU1689730718'),
#             ('LU0144746509', 'LU1689730809'),
#             ('LU0144746509', 'LU1689730981'),
#             ('LU1373033965', 'LU1689730718'),
#             ('LU1373033965', 'LU1689730809'),
#             ('LU1373033965', 'LU1689730981')],
#            names=['instrument', 'shareclass'], length=471)

# %%
test = pd.DataFrame(index=MI)
All = slice(None)
test.loc[(bucket.get_instruments().index, isins[0]), ] = bucket.get_distribution_vector()
test
# Out:
#                            290018_1  267100_1  144120_1  265000_1  264293_1  \
# instrument   shareclass
# 294880_1     LU1689730718       NaN       NaN       NaN       NaN       NaN
#              LU1689730809       NaN       NaN       NaN       NaN       NaN
#              LU1689730981       NaN       NaN       NaN       NaN       NaN
# 294864_1     LU1689730718       NaN       NaN       NaN       NaN       NaN
#              LU1689730809       NaN       NaN       NaN       NaN       NaN
# ...                             ...       ...       ...       ...       ...
# LU0144746509 LU1689730809       NaN       NaN       NaN       NaN       NaN
#              LU1689730981       NaN       NaN       NaN       NaN       NaN
# LU1373033965 LU1689730718       NaN       NaN       NaN       NaN       NaN
#              LU1689730809       NaN       NaN       NaN       NaN       NaN
#              LU1689730981       NaN       NaN       NaN       NaN       NaN
#
#                            155000_1  152001_1  XS1603892149  XS1872038218  \
# instrument   shareclass
# 294880_1     LU1689730718       NaN       NaN           NaN           NaN
#              LU1689730809       NaN       NaN           NaN           NaN
#              LU1689730981       NaN       NaN           NaN           NaN
# 294864_1     LU1689730718       NaN       NaN           NaN           NaN
#              LU1689730809       NaN       NaN           NaN           NaN
# ...                             ...       ...           ...           ...
# LU0144746509 LU1689730809       NaN       NaN           NaN           NaN
#              LU1689730981       NaN       NaN           NaN           NaN
# LU1373033965 LU1689730718       NaN       NaN           NaN           NaN
#              LU1689730809       NaN       NaN           NaN           NaN
#              LU1689730981       NaN       NaN           NaN           NaN
#
#                            BE0002597756  ...  DE000A2GSFF1  XS0940293763  \
# instrument   shareclass                  ...
# 294880_1     LU1689730718           NaN  ...           NaN           NaN
#              LU1689730809           NaN  ...           NaN           NaN
#              LU1689730981           NaN  ...           NaN           NaN
# 294864_1     LU1689730718           NaN  ...           NaN           NaN
#              LU1689730809           NaN  ...           NaN           NaN
# ...                                 ...  ...           ...           ...
# LU0144746509 LU1689730809           NaN  ...           NaN           NaN
#              LU1689730981           NaN  ...           NaN           NaN
# LU1373033965 LU1689730718           NaN  ...           NaN           NaN
#              LU1689730809           NaN  ...           NaN           NaN
#              LU1689730981           NaN  ...           NaN           NaN
#
#                            BE0002601798  AT0000A1LHT0  XS2123970241  \
# instrument   shareclass
# 294880_1     LU1689730718           NaN           NaN           NaN
#              LU1689730809           NaN           NaN           NaN
#              LU1689730981           NaN           NaN           NaN
# 294864_1     LU1689730718           NaN           NaN           NaN
#              LU1689730809           NaN           NaN           NaN
# ...                                 ...           ...           ...
# LU0144746509 LU1689730809           NaN           NaN           NaN
#              LU1689730981           NaN           NaN           NaN
# LU1373033965 LU1689730718           NaN           NaN           NaN
#              LU1689730809           NaN           NaN           NaN
#              LU1689730981           NaN           NaN           NaN
#
#                            XS2221845683  IE00B3T9LM79  LU1663872726  \
# instrument   shareclass
# 294880_1     LU1689730718           NaN           NaN           NaN
#              LU1689730809           NaN           NaN           NaN
#              LU1689730981           NaN           NaN           NaN
# 294864_1     LU1689730718           NaN           NaN           NaN
#              LU1689730809           NaN           NaN           NaN
# ...                                 ...           ...           ...
# LU0144746509 LU1689730809           NaN           NaN           NaN
#              LU1689730981           NaN           NaN           NaN
# LU1373033965 LU1689730718           NaN           NaN           NaN
#              LU1689730809           NaN           NaN           NaN
#              LU1689730981           NaN           NaN           NaN
#
#                            LU0144746509  LU1373033965
# instrument   shareclass
# 294880_1     LU1689730718           NaN           NaN
#              LU1689730809           NaN           NaN
#              LU1689730981           NaN           NaN
# 294864_1     LU1689730718           NaN           NaN
#              LU1689730809           NaN           NaN
# ...                                 ...           ...
# LU0144746509 LU1689730809           NaN           NaN
#              LU1689730981           NaN           NaN
# LU1373033965 LU1689730718           NaN           NaN
#              LU1689730809           NaN           NaN
#              LU1689730981           NaN           NaN
#
# [471 rows x 150 columns]
